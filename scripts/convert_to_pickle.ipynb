# %%
# Take Combined CSV of all data and convert to pickle model
import pandas as pd 
import os

data_loc = 'C:/Users/Harry/Desktop/ECEC487/data'
csv = 'combined_csv.csv'
pickle_path = 'C:/Users/Harry/Desktop/ECEC487/data/pickledDf.pkl'

data_path = os.path.join('.', data_loc)
data_file = os.path.join(data_path, csv)

data = pd.read_csv(data_file) 

# Preview the first 5 lines of the loaded data 
data.head()

# Convert Data into Pickle (serialize) object to file.
data.to_pickle(pickle_path)

# Unpickle file and view
unpickled_df = pd.read_pickle(pickle_path)
unpickled_df
# Out:
#          Unnamed: 0     F4-C4      C4-P4      P4-O2      C4-A1  Label
# 0                 0  2.915140  16.559829 -15.094628 -16.163004      0
# 1                 1  2.487790  16.010379 -15.552503 -20.283883      0
# 2                 2  2.060440  15.552503 -15.918803 -22.878510      0
# 3                 3  1.694139  15.247253 -16.132479 -24.618437      0
# 4                 4  1.449939  15.125153 -16.193529 -25.961538      0
# 5                 5  1.388889  15.094628 -16.132479 -27.029915      0
# 6                 6  1.419414  15.094628 -16.010379 -28.647741      0
# 7                 7  1.388889  15.033578 -15.888278 -30.815018      0
# 8                 8  1.297314  14.880952 -15.705128 -32.463370      0
# 9                 9  1.144689  14.667277 -15.399878 -32.829670      0
# 10               10  0.992063  14.484127 -15.003053 -32.127595      0
# 11               11  0.869963  14.484127 -14.453602 -30.296093      0
# ...
